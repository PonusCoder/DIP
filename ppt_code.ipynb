# %% [markdown]
# <a href="https://colab.research.google.com/github/PonusCoder/DIP/blob/main/ppt_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read the image
image_original = cv2.imread('images.jpg')
image = cv2.resize(image_original, (400, 400))

# %%
# Apply filters for edge detection
edges = cv2.Canny(image, 100, 200)

# %%
# Apply filters for texture extraction
blur = cv2.blur(image, (5, 5))
laplacian = cv2.Laplacian(image, cv2.CV_64F)
sobel_x = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=3)
sobel_y = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=3)

# %%
# Display the images
plt.figure(figsize=(12, 8))

# %%
plt.subplot(231)
plt.imshow(image, cmap='gray')
plt.title('Original Image')
# Out:
# Text(0.5, 1.0, 'Original Image')

# %%
plt.subplot(232)
plt.imshow(edges, cmap='gray')
plt.title('Edges')
# Out:
# Text(0.5, 1.0, 'Edges')

# %%
plt.subplot(233)
plt.imshow(blur, cmap='gray')
plt.title('Blur')
# Out:
# Text(0.5, 1.0, 'Blur')

# %%
plt.subplot(234)
plt.imshow(laplacian, cmap='gray')
plt.title('Laplacian')
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'Laplacian')

# %%
plt.subplot(235)
plt.imshow(sobel_x, cmap='gray')
plt.title('Sobel X')
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'Sobel X')

# %%
plt.subplot(236)
plt.imshow(sobel_y, cmap='gray')
plt.title('Sobel Y')
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5, 1.0, 'Sobel Y')

# %%
plt.tight_layout()
plt.show()
